# %% [markdown]
# # GAN

# %%
import torch
import torch.nn as nn
import torch.nn.init
import torch.optim as optim

import torchvision
import torchvision.datasets as dsets
import torchvision.transforms as transforms

import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Prepare MNIST Data

# %%
mnist_train = dsets.MNIST(root='data/',
                          train=True,
                          transform=transforms.ToTensor(),
                          download=True)

# %%
batch_size = 100

train_loader  = torch.utils.data.DataLoader(dataset=mnist_train,
                                           batch_size=batch_size,
                                           shuffle=False)

# %%
def imshow(img, title):
    npimg = img.numpy()
    fig = plt.figure(figsize = (5, 15))
    plt.imshow(np.transpose(npimg,(1,2,0)))
    plt.title(title)
    plt.show()

# %%
images, labels = iter(train_loader).next()
imshow(torchvision.utils.make_grid(images, normalize=True), "Train Image")

# %% [markdown]
# ## Define Model

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.discriminator = nn.Sequential(
            nn.Conv2d(1, 100, 4, stride=2, padding=1),
            nn.BatchNorm2d(100),
            nn.LeakyReLU(0.2),
            nn.Conv2d(100, 200, 4, stride=2, padding=1),
            nn.BatchNorm2d(200),
            nn.LeakyReLU(0.2),
            nn.Conv2d(200, 100, 4, stride=1, padding=0),
            nn.BatchNorm2d(100),
            nn.LeakyReLU(0.2),
            nn.Conv2d(100, 1, 4, stride=1, padding=0),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        out = self.discriminator(x)
        out = out.view(-1, 1)
        return out

# %%
D = Discriminator().cuda()

# %%
D(images.cuda()).shape
# Out:
# torch.Size([100, 1])

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.generator = nn.Sequential(
            nn.ConvTranspose2d(100, 200, 4, stride=1, padding=0),
            nn.BatchNorm2d(200),
            nn.ReLU(),
            nn.ConvTranspose2d(200, 400, 4, stride=1, padding=0),
            nn.BatchNorm2d(400),
            nn.ReLU(),
            nn.ConvTranspose2d(400, 200, 4, stride=2, padding=1),
            nn.BatchNorm2d(200),
            nn.ReLU(),
            nn.ConvTranspose2d(200, 1, 4, stride=2, padding=1),
            nn.Sigmoid()
        )
        
    def forward(self, z):
        z = z.view(-1, 100, 1, 1)
        out = self.generator(z)
        return out

# %%
G = Generator().cuda()

# %%
z = torch.randn((batch_size, 100)).cuda()
G(z).shape
# Out:
# torch.Size([100, 1, 28, 28])

# %% [markdown]
# ## Train Model

# %%
def gan_loss(x, target_is_real):
    
    loss = nn.BCELoss()
    
    if target_is_real : 
        target_tensor = torch.ones(batch_size, 1)
    else :
        target_tensor = torch.zeros(batch_size, 1)
        
    return loss(x, target_tensor.cuda())

# %%
G_optimizer = optim.Adam(G.parameters(), lr=0.0001)
D_optimizer = optim.Adam(D.parameters(), lr=0.0001)

# %%
num_epochs = 30

# %%
for epoch in range(num_epochs):
        
    total_batch = len(mnist_train) // batch_size
    
    for i, (images, labels) in enumerate(train_loader):
        
        images = images.cuda()
            
        prob_real = D(images)
        D_loss_real = gan_loss(prob_real, True)

        z = torch.randn((batch_size, 100)).cuda()
        fake_images = G(z)
        
        prob_fake = D(fake_images)
        D_loss_fake = gan_loss(prob_fake, False)
        
        D_loss = D_loss_real + D_loss_fake
        
        D.zero_grad()
        D_loss.backward()
        D_optimizer.step()
        
        z = torch.randn((batch_size, 100)).cuda()
        fake_images = G(z)
        
        prob_fake = D(fake_images)
        G_loss = gan_loss(prob_fake, True)
        
        G.zero_grad()
        G_loss.backward()
        G_optimizer.step()
        
        if (i+1) % 100 == 0:
            print('Epoch [%d/%d], lter [%d/%d], D_Loss: %.4f, G_Loss: %.4f'
                 %(epoch+1, num_epochs, i+1, total_batch, D_loss.item(), G_loss.item()))
# Out:
# Epoch [1/30], lter [100/600], D_Loss: 0.0535, G_Loss: 4.3334
# Epoch [1/30], lter [200/600], D_Loss: 0.0411, G_Loss: 5.2751
# Epoch [1/30], lter [300/600], D_Loss: 0.0180, G_Loss: 5.4700
# Epoch [1/30], lter [400/600], D_Loss: 0.0125, G_Loss: 5.2626
# Epoch [1/30], lter [500/600], D_Loss: 0.0371, G_Loss: 5.9905
# Epoch [1/30], lter [600/600], D_Loss: 0.0664, G_Loss: 5.7028
# Epoch [2/30], lter [100/600], D_Loss: 0.0111, G_Loss: 5.7429
# Epoch [2/30], lter [200/600], D_Loss: 0.0113, G_Loss: 6.5747
# Epoch [2/30], lter [300/600], D_Loss: 0.0215, G_Loss: 5.2639
# Epoch [2/30], lter [400/600], D_Loss: 0.0080, G_Loss: 6.5323
# Epoch [2/30], lter [500/600], D_Loss: 0.0196, G_Loss: 4.9718
# Epoch [2/30], lter [600/600], D_Loss: 0.0054, G_Loss: 6.2339
# Epoch [3/30], lter [100/600], D_Loss: 0.0027, G_Loss: 6.7664
# Epoch [3/30], lter [200/600], D_Loss: 0.0467, G_Loss: 4.8027
# Epoch [3/30], lter [300/600], D_Loss: 0.0262, G_Loss: 5.7019
# Epoch [3/30], lter [400/600], D_Loss: 0.0188, G_Loss: 7.5774
# Epoch [3/30], lter [500/600], D_Loss: 0.0271, G_Loss: 8.0981
# Epoch [3/30], lter [600/600], D_Loss: 0.0436, G_Loss: 5.0859
# Epoch [4/30], lter [100/600], D_Loss: 0.0257, G_Loss: 7.4386
# Epoch [4/30], lter [200/600], D_Loss: 0.0350, G_Loss: 7.0357
# Epoch [4/30], lter [300/600], D_Loss: 0.2359, G_Loss: 4.7015
# Epoch [4/30], lter [400/600], D_Loss: 0.0730, G_Loss: 7.3570
# Epoch [4/30], lter [500/600], D_Loss: 0.0987, G_Loss: 6.8220
# Epoch [4/30], lter [600/600], D_Loss: 0.2391, G_Loss: 2.1491
# Epoch [5/30], lter [100/600], D_Loss: 0.2130, G_Loss: 3.6082
# Epoch [5/30], lter [200/600], D_Loss: 0.0740, G_Loss: 5.0595
# Epoch [5/30], lter [300/600], D_Loss: 0.2562, G_Loss: 3.9470
# Epoch [5/30], lter [400/600], D_Loss: 0.1582, G_Loss: 4.9412
# Epoch [5/30], lter [500/600], D_Loss: 0.1250, G_Loss: 4.7910
# Epoch [5/30], lter [600/600], D_Loss: 0.3815, G_Loss: 1.5264
# Epoch [6/30], lter [100/600], D_Loss: 0.3226, G_Loss: 2.9478
# Epoch [6/30], lter [200/600], D_Loss: 0.4677, G_Loss: 4.1152
# Epoch [6/30], lter [300/600], D_Loss: 0.1868, G_Loss: 4.7549
# Epoch [6/30], lter [400/600], D_Loss: 0.3369, G_Loss: 4.1765
# Epoch [6/30], lter [500/600], D_Loss: 0.3314, G_Loss: 3.6485
# Epoch [6/30], lter [600/600], D_Loss: 0.5132, G_Loss: 4.8012
# Epoch [7/30], lter [100/600], D_Loss: 0.5353, G_Loss: 2.2696
# Epoch [7/30], lter [200/600], D_Loss: 0.4045, G_Loss: 3.2534
# Epoch [7/30], lter [300/600], D_Loss: 0.3545, G_Loss: 3.1297
# Epoch [7/30], lter [400/600], D_Loss: 0.3052, G_Loss: 4.5719
# Epoch [7/30], lter [500/600], D_Loss: 0.3982, G_Loss: 3.3010
# Epoch [7/30], lter [600/600], D_Loss: 0.1975, G_Loss: 6.1715
# Epoch [8/30], lter [100/600], D_Loss: 0.3027, G_Loss: 3.0341
# Epoch [8/30], lter [200/600], D_Loss: 0.6896, G_Loss: 4.2188
# Epoch [8/30], lter [300/600], D_Loss: 0.4129, G_Loss: 3.7645
# Epoch [8/30], lter [400/600], D_Loss: 0.7053, G_Loss: 0.9247
# Epoch [8/30], lter [500/600], D_Loss: 0.6473, G_Loss: 2.1469
# Epoch [8/30], lter [600/600], D_Loss: 0.3303, G_Loss: 3.9123
# Epoch [9/30], lter [100/600], D_Loss: 0.4633, G_Loss: 2.4129
# Epoch [9/30], lter [200/600], D_Loss: 0.4432, G_Loss: 2.5691
# Epoch [9/30], lter [300/600], D_Loss: 0.8582, G_Loss: 1.9157
# Epoch [9/30], lter [400/600], D_Loss: 0.4754, G_Loss: 2.6658
# Epoch [9/30], lter [500/600], D_Loss: 0.5958, G_Loss: 1.8647
# Epoch [9/30], lter [600/600], D_Loss: 0.7459, G_Loss: 2.6849
# Epoch [10/30], lter [100/600], D_Loss: 0.7091, G_Loss: 2.4317
# Epoch [10/30], lter [200/600], D_Loss: 0.6438, G_Loss: 3.4294
# Epoch [10/30], lter [300/600], D_Loss: 0.3561, G_Loss: 3.1632
# Epoch [10/30], lter [400/600], D_Loss: 0.6185, G_Loss: 2.8083
# Epoch [10/30], lter [500/600], D_Loss: 0.5270, G_Loss: 2.3491
# Epoch [10/30], lter [600/600], D_Loss: 0.6479, G_Loss: 3.3339
# Epoch [11/30], lter [100/600], D_Loss: 0.5586, G_Loss: 1.7264
# Epoch [11/30], lter [200/600], D_Loss: 0.4513, G_Loss: 1.9843
# Epoch [11/30], lter [300/600], D_Loss: 0.9074, G_Loss: 2.1618
# Epoch [11/30], lter [400/600], D_Loss: 0.7960, G_Loss: 1.8714
# Epoch [11/30], lter [500/600], D_Loss: 0.6643, G_Loss: 2.0004
# Epoch [11/30], lter [600/600], D_Loss: 0.5572, G_Loss: 2.6256
# Epoch [12/30], lter [100/600], D_Loss: 0.4951, G_Loss: 1.7462
# Epoch [12/30], lter [200/600], D_Loss: 0.7277, G_Loss: 2.5221
# Epoch [12/30], lter [300/600], D_Loss: 0.8333, G_Loss: 1.8239
# Epoch [12/30], lter [400/600], D_Loss: 1.2701, G_Loss: 0.9844
# Epoch [12/30], lter [500/600], D_Loss: 0.7532, G_Loss: 1.2699
# Epoch [12/30], lter [600/600], D_Loss: 0.7945, G_Loss: 1.8634
# Epoch [13/30], lter [100/600], D_Loss: 0.5473, G_Loss: 2.3698
# Epoch [13/30], lter [200/600], D_Loss: 0.4830, G_Loss: 3.0240
# Epoch [13/30], lter [300/600], D_Loss: 0.7808, G_Loss: 1.8895
# Epoch [13/30], lter [400/600], D_Loss: 0.4382, G_Loss: 2.4358
# Epoch [13/30], lter [500/600], D_Loss: 0.6006, G_Loss: 2.4697
# Epoch [13/30], lter [600/600], D_Loss: 0.7930, G_Loss: 1.9759
# Epoch [14/30], lter [100/600], D_Loss: 0.7348, G_Loss: 1.9894
# Epoch [14/30], lter [200/600], D_Loss: 0.4799, G_Loss: 2.3344
# Epoch [14/30], lter [300/600], D_Loss: 1.0992, G_Loss: 1.5316
# Epoch [14/30], lter [400/600], D_Loss: 0.8135, G_Loss: 2.0860
# Epoch [14/30], lter [500/600], D_Loss: 0.4902, G_Loss: 2.4725
# Epoch [14/30], lter [600/600], D_Loss: 1.0389, G_Loss: 1.9134
# Epoch [15/30], lter [100/600], D_Loss: 0.7011, G_Loss: 2.1808
# Epoch [15/30], lter [200/600], D_Loss: 0.5909, G_Loss: 2.3269
# Epoch [15/30], lter [300/600], D_Loss: 0.8138, G_Loss: 1.7314
# Epoch [15/30], lter [400/600], D_Loss: 0.4539, G_Loss: 2.7194
# Epoch [15/30], lter [500/600], D_Loss: 1.4493, G_Loss: 1.0122
# Epoch [15/30], lter [600/600], D_Loss: 0.7286, G_Loss: 1.8205
# Epoch [16/30], lter [100/600], D_Loss: 0.5246, G_Loss: 1.6869
# Epoch [16/30], lter [200/600], D_Loss: 0.4817, G_Loss: 2.4525
# Epoch [16/30], lter [300/600], D_Loss: 1.4307, G_Loss: 0.8231
# Epoch [16/30], lter [400/600], D_Loss: 0.6393, G_Loss: 2.4933
# Epoch [16/30], lter [500/600], D_Loss: 1.0544, G_Loss: 1.3696
# Epoch [16/30], lter [600/600], D_Loss: 0.6054, G_Loss: 1.6550
# Epoch [17/30], lter [100/600], D_Loss: 0.7468, G_Loss: 1.7633
# Epoch [17/30], lter [200/600], D_Loss: 0.4400, G_Loss: 1.9341
# Epoch [17/30], lter [300/600], D_Loss: 1.3059, G_Loss: 1.0384
# Epoch [17/30], lter [400/600], D_Loss: 0.6195, G_Loss: 2.3506
# Epoch [17/30], lter [500/600], D_Loss: 0.7478, G_Loss: 1.7097
# Epoch [17/30], lter [600/600], D_Loss: 0.7864, G_Loss: 1.8327
# Epoch [18/30], lter [100/600], D_Loss: 0.6749, G_Loss: 1.6341
# Epoch [18/30], lter [200/600], D_Loss: 0.7372, G_Loss: 2.3213
# Epoch [18/30], lter [300/600], D_Loss: 1.4449, G_Loss: 1.4740
# Epoch [18/30], lter [400/600], D_Loss: 0.5879, G_Loss: 1.6732
# Epoch [18/30], lter [500/600], D_Loss: 0.5819, G_Loss: 1.9074
# Epoch [18/30], lter [600/600], D_Loss: 0.5613, G_Loss: 1.6790
# Epoch [19/30], lter [100/600], D_Loss: 0.6938, G_Loss: 1.3925
# Epoch [19/30], lter [200/600], D_Loss: 0.6548, G_Loss: 1.8578
# Epoch [19/30], lter [300/600], D_Loss: 1.4653, G_Loss: 1.0172
# Epoch [19/30], lter [400/600], D_Loss: 0.4650, G_Loss: 2.5680
# Epoch [19/30], lter [500/600], D_Loss: 0.5780, G_Loss: 2.1771
# Epoch [19/30], lter [600/600], D_Loss: 0.6858, G_Loss: 1.4524
# Epoch [20/30], lter [100/600], D_Loss: 1.0610, G_Loss: 1.8138
# Epoch [20/30], lter [200/600], D_Loss: 0.5728, G_Loss: 1.5741
# Epoch [20/30], lter [300/600], D_Loss: 0.8614, G_Loss: 1.6807
# Epoch [20/30], lter [400/600], D_Loss: 0.7576, G_Loss: 1.9900
# Epoch [20/30], lter [500/600], D_Loss: 0.8290, G_Loss: 1.5005
# Epoch [20/30], lter [600/600], D_Loss: 0.6538, G_Loss: 1.3956
# Epoch [21/30], lter [100/600], D_Loss: 0.5346, G_Loss: 1.5736
# Epoch [21/30], lter [200/600], D_Loss: 0.7077, G_Loss: 1.9930
# Epoch [21/30], lter [300/600], D_Loss: 1.4150, G_Loss: 1.2404
# Epoch [21/30], lter [400/600], D_Loss: 0.9991, G_Loss: 0.9387
# Epoch [21/30], lter [500/600], D_Loss: 0.6164, G_Loss: 2.1567
# Epoch [21/30], lter [600/600], D_Loss: 0.5055, G_Loss: 1.9049
# Epoch [22/30], lter [100/600], D_Loss: 0.6356, G_Loss: 1.6259
# Epoch [22/30], lter [200/600], D_Loss: 0.8368, G_Loss: 1.6395
# Epoch [22/30], lter [300/600], D_Loss: 0.8726, G_Loss: 1.7858
# Epoch [22/30], lter [400/600], D_Loss: 0.8512, G_Loss: 1.8952
# Epoch [22/30], lter [500/600], D_Loss: 0.5709, G_Loss: 2.3079
# Epoch [22/30], lter [600/600], D_Loss: 0.5844, G_Loss: 1.8354
# Epoch [23/30], lter [100/600], D_Loss: 0.6243, G_Loss: 2.2441
# Epoch [23/30], lter [200/600], D_Loss: 0.8875, G_Loss: 1.6363
# Epoch [23/30], lter [300/600], D_Loss: 1.1624, G_Loss: 1.5481
# Epoch [23/30], lter [400/600], D_Loss: 1.0447, G_Loss: 1.0589
# Epoch [23/30], lter [500/600], D_Loss: 0.7225, G_Loss: 1.9199
# Epoch [23/30], lter [600/600], D_Loss: 0.8487, G_Loss: 1.4981
# Epoch [24/30], lter [100/600], D_Loss: 0.5442, G_Loss: 1.6202
# Epoch [24/30], lter [200/600], D_Loss: 0.6979, G_Loss: 1.5208
# Epoch [24/30], lter [300/600], D_Loss: 1.3813, G_Loss: 0.6144
# Epoch [24/30], lter [400/600], D_Loss: 0.9336, G_Loss: 1.7143
# Epoch [24/30], lter [500/600], D_Loss: 0.5209, G_Loss: 1.5492
# Epoch [24/30], lter [600/600], D_Loss: 0.6904, G_Loss: 1.7008
# Epoch [25/30], lter [100/600], D_Loss: 0.7653, G_Loss: 1.8455
# Epoch [25/30], lter [200/600], D_Loss: 0.9595, G_Loss: 1.2400
# Epoch [25/30], lter [300/600], D_Loss: 1.1896, G_Loss: 1.3865
# Epoch [25/30], lter [400/600], D_Loss: 0.9944, G_Loss: 1.1776
# Epoch [25/30], lter [500/600], D_Loss: 0.9388, G_Loss: 1.7582
# Epoch [25/30], lter [600/600], D_Loss: 0.4645, G_Loss: 1.7951
# Epoch [26/30], lter [100/600], D_Loss: 0.8568, G_Loss: 1.4664
# Epoch [26/30], lter [200/600], D_Loss: 0.9395, G_Loss: 1.5712
# Epoch [26/30], lter [300/600], D_Loss: 1.1132, G_Loss: 1.3211
# Epoch [26/30], lter [400/600], D_Loss: 0.8566, G_Loss: 1.3536
# Epoch [26/30], lter [500/600], D_Loss: 1.0142, G_Loss: 1.5662
# Epoch [26/30], lter [600/600], D_Loss: 0.5181, G_Loss: 1.4525
# Epoch [27/30], lter [100/600], D_Loss: 0.5242, G_Loss: 1.9596
# Epoch [27/30], lter [200/600], D_Loss: 0.7500, G_Loss: 1.5923
# Epoch [27/30], lter [300/600], D_Loss: 0.8945, G_Loss: 1.7788
# Epoch [27/30], lter [400/600], D_Loss: 0.8530, G_Loss: 1.2462
# Epoch [27/30], lter [500/600], D_Loss: 0.6812, G_Loss: 1.6897
# Epoch [27/30], lter [600/600], D_Loss: 0.4201, G_Loss: 1.6232
# Epoch [28/30], lter [100/600], D_Loss: 0.7987, G_Loss: 2.0700
# Epoch [28/30], lter [200/600], D_Loss: 0.6125, G_Loss: 1.4927
# Epoch [28/30], lter [300/600], D_Loss: 0.9825, G_Loss: 1.5092
# Epoch [28/30], lter [400/600], D_Loss: 0.7423, G_Loss: 1.4756
# Epoch [28/30], lter [500/600], D_Loss: 1.0021, G_Loss: 1.7163
# Epoch [28/30], lter [600/600], D_Loss: 0.3465, G_Loss: 1.2912
# Epoch [29/30], lter [100/600], D_Loss: 0.9610, G_Loss: 1.3903
# Epoch [29/30], lter [200/600], D_Loss: 0.8528, G_Loss: 1.5985
# Epoch [29/30], lter [300/600], D_Loss: 0.5789, G_Loss: 1.8544
# Epoch [29/30], lter [400/600], D_Loss: 0.7226, G_Loss: 1.7052
# Epoch [29/30], lter [500/600], D_Loss: 0.9873, G_Loss: 1.9691
# Epoch [29/30], lter [600/600], D_Loss: 0.6145, G_Loss: 1.4634
# Epoch [30/30], lter [100/600], D_Loss: 0.9975, G_Loss: 1.3135
# Epoch [30/30], lter [200/600], D_Loss: 0.6644, G_Loss: 1.9309
# Epoch [30/30], lter [300/600], D_Loss: 1.1117, G_Loss: 1.1482
# Epoch [30/30], lter [400/600], D_Loss: 0.7294, G_Loss: 1.6636
# Epoch [30/30], lter [500/600], D_Loss: 0.5040, G_Loss: 1.7924
# Epoch [30/30], lter [600/600], D_Loss: 0.3731, G_Loss: 2.3290

# %% [markdown]
# ## Test Model

# %%
G.eval()

z = torch.randn((batch_size, 100)).cuda()
images = G(z)
imshow(torchvision.utils.make_grid(images.data.cpu(), normalize=True), "Test Image")
