# %% [markdown]
# # Classification

# %% [markdown]
# [Load and return the iris dataset (classification)](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)

# %% [markdown]
# @ Iris Data
#
# Data Set Information:
#
# This is perhaps the best known database to be found in the pattern recognition literature. Fisher's paper is a classic in the field and is referenced frequently to this day. (See Duda & Hart, for example.) The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Predicted attribute: class of iris plant.
#
# This is an exceedingly simple domain.
#
# This data differs from the data presented in Fishers article (identified by Steve Chadwick, spchadwick '@' espeedaz.net ). The 35th sample should be: 4.9,3.1,1.5,0.2,"Iris-setosa" where the error is in the fourth feature. The 38th sample: 4.9,3.6,1.4,0.1,"Iris-setosa" where the errors are in the second and third features.
#
#
# Attribute Information:
#
# 1. sepal(꽃잎) length in cm
# 2. sepal(꽃잎) width in cm
# 3. petal(꽃받침) length in cm
# 4. petal(꽃받침) width in cm
#
# Class information:
#
# -- Iris Setosa (부채붓꽃)
# -- Iris Versicolour (...)
# -- Iris Virginica (...)

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
# Only using sepal information
x = iris.data[:, :2]

# Setosa v.s. Not Setosa
y = (iris.target >= 1).astype(int)

x.shape, y.shape
# Out:
# ((150, 2), (150,))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x[:, 0], x[:, 1], c=y)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Split Data: Train data, Validation Data

# %%
import numpy as np

# %%
train_len = 100
train_idxs = np.random.choice(len(x), train_len, replace=False)
train_x = x[train_idxs]
train_y = y[train_idxs]

# %%
plt.scatter(train_x[:, 0], train_x[:, 1], c=train_y)
plt.colorbar()
plt.show()

# %%
val_idxs = [idx for idx in range(len(x)) if idx not in train_idxs]
val_x = x[val_idxs]
val_y = y[val_idxs]

# %%
plt.scatter(val_x[:, 0], val_x[:, 1], c=val_y)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Set Models

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_lr = LogisticRegression(fit_intercept=True,
                              solver='lbfgs',
                              random_state=0) # Loss function is fixed to BCE.

# %% [markdown]
# #### DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier(criterion='gini',
                                  splitter='best', # {“best”, “random”}
                                  max_depth=10,
                                  random_state=0)

# %% [markdown]
# #### SVC

# %%
from sklearn.svm import SVC

# %%
model_svc = SVC(C=1.0, kernel='rbf', gamma='scale')

# %% [markdown]
# ### Train and Validate

# %%
models = [model_lr, model_dt, model_svc]

# %%
def accuracy(pre, y):
    return sum(pre==y)/len(y)

# %% [markdown]
# #### Train

# %%
for model in models:
    model.fit(train_x, train_y)
    pre = model.predict(train_x)
    
    acc = accuracy(pre, train_y)
    
    print(model, acc)
# Out:
# LogisticRegression(random_state=0) 1.0
# DecisionTreeClassifier(max_depth=10, random_state=0) 1.0
# SVC() 1.0

# %% [markdown]
# #### Validate

# %%
for model in models:
#     model.fit(val_x, val_y)
    pre = model.predict(val_x)
    
    acc = accuracy(pre, val_y)
    
    print(model, acc)
# Out:
# LogisticRegression(random_state=0) 1.0
# DecisionTreeClassifier(max_depth=10, random_state=0) 0.98
# SVC() 1.0

# %% [markdown]
# #### Explain

# %%
h = .02
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
for model in models:
    pre = model.predict(np.c_[xx.ravel(), yy.ravel()])
    pre = pre.reshape(xx.shape)
    plt.contourf(xx, yy, pre, cmap=plt.cm.coolwarm, alpha=0.8)

    plt.scatter(val_x[:, 0], val_x[:, 1], c=val_y, cmap=plt.cm.coolwarm)
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(model)
    plt.show()

# %% [markdown]
# ### Select Model

# %%
model_best = model_lr

# %% [markdown]
# # Multi-label classification

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
x = iris.data[:, :2]
y = iris.target
x.shape, y.shape
# Out:
# ((150, 2), (150,))

# %%
plt.scatter(x[:, 0], x[:, 1], c=y, cmap='viridis')
plt.colorbar()
plt.show()

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier

# %%
model_lr_ovr = OneVsRestClassifier(LogisticRegression())
model_lr_ovr.fit(x, y)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression())

# %%
model_lr_ovo = OneVsOneClassifier(LogisticRegression())
model_lr_ovo.fit(x, y)
# Out:
# OneVsOneClassifier(estimator=LogisticRegression())

# %%
model_lr_ovr.estimators_, model_lr_ovo.estimators_
# Out:
# ([LogisticRegression(), LogisticRegression(), LogisticRegression()],
#  (LogisticRegression(), LogisticRegression(), LogisticRegression()))

# %%
svc = SVC(C=10, kernel='poly', decision_function_shape='ovr')

# %%
h = .02
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
for model in [svc_ovo, svc_ovr]:
    pre = model.predict(np.c_[xx.ravel(), yy.ravel()])
    pre = pre.reshape(xx.shape)
    plt.contourf(xx, yy, pre, cmap='viridis', alpha=0.1)

    plt.scatter(x[:, 0], x[:, 1], c=y, cmap='viridis')
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(model)
    plt.show()

# %% [markdown]
# # Parameter Search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
param_grid = [
  {'C': [1, 10], 'kernel': ['linear']},
  {'C': [0.1, 1], 'kernel': ['rbf']},
 ]

# %% [markdown]
# ### Predifined Split

# %%
from sklearn.model_selection import PredefinedSplit
split_index = [-1 if idx in train_idxs else 0 for idx in range(len(x))]
pds = PredefinedSplit(test_fold=split_index)

# %%
svc = SVC()
clf = GridSearchCV(svc, param_grid, cv=pds)

# %%
clf.fit(x, y)
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ..., -1,  0])),
#              estimator=SVC(),
#              param_grid=[{'C': [1, 10], 'kernel': ['linear']},
#                          {'C': [0.1, 1], 'kernel': ['rbf']}])

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00099754, 0.        , 0.00099683, 0.00099826]),
#  'std_fit_time': array([0., 0., 0., 0.]),
#  'mean_score_time': array([0.0009973 , 0.00099587, 0.        , 0.        ]),
#  'std_score_time': array([0., 0., 0., 0.]),
#  'param_C': masked_array(data=[1, 10, 0.1, 1],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'linear', 'rbf', 'rbf'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 0.1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'rbf'}],
#  'split0_test_score': array([1.  , 0.98, 0.9 , 1.  ]),
#  'mean_test_score': array([1.  , 0.98, 0.9 , 1.  ]),
#  'std_test_score': array([0., 0., 0., 0.]),
#  'rank_test_score': array([1, 3, 4, 1])}

# %% [markdown]
# ### K-fold Cross Validation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5)

# %%
svc = SVC()
clf = GridSearchCV(svc, param_grid, cv=kf)

# %%
clf.fit(x, y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=SVC(),
#              param_grid=[{'C': [1, 10], 'kernel': ['linear']},
#                          {'C': [0.1, 1], 'kernel': ['rbf']}])

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.0007978 , 0.00059824, 0.00079746, 0.00059848]),
#  'std_fit_time': array([0.0003989 , 0.00048846, 0.00039873, 0.00048866]),
#  'mean_score_time': array([0.00079775, 0.        , 0.00039878, 0.0001996 ]),
#  'std_score_time': array([0.00039887, 0.        , 0.0004884 , 0.00039921]),
#  'param_C': masked_array(data=[1, 10, 0.1, 1],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'linear', 'rbf', 'rbf'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 0.1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'rbf'}],
#  'split0_test_score': array([1., 1., 0., 1.]),
#  'split1_test_score': array([1.        , 0.96666667, 0.56666667, 0.96666667]),
#  'split2_test_score': array([1.        , 1.        , 0.96666667, 1.        ]),
#  'split3_test_score': array([1.        , 1.        , 0.96666667, 0.96666667]),
#  'split4_test_score': array([1., 1., 1., 1.]),
#  'mean_test_score': array([1.        , 0.99333333, 0.7       , 0.98666667]),
#  'std_test_score': array([0.        , 0.01333333, 0.38470768, 0.01632993]),
#  'rank_test_score': array([1, 2, 4, 3])}
